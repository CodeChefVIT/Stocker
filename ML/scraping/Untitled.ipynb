# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg' 
plt.style.use('fivethirtyeight')
data = pd.read_csv("daily_top_gainers.csv")

data
# Out:
#                  Company  % Change
# 0       Dr. Reddy's Labs      6.19
# 1          IndusInd Bank      4.47
# 2             Tata Steel      4.25
# 3           Grasim Inds.      3.36
# 4   Bharti Infratel Ltd.      3.15
# 5                    UPL      2.85
# 6                  Cipla      2.81
# 7            Sun Pharma.      2.15
# 8          Eicher Motors      1.65
# 9        Bajaj Finance L      1.38
# 10     GAIL (India) Ltd.      1.23
# 11             JSW Steel      1.23
# 12      UltraTech Cement      1.08
# 13                   L&T      0.93
# 14                   SBI      0.92
# 15        Axis Bank Ltd.      0.88
# 16              ITC Ltd.      0.67
# 17            Coal India      0.57
# 18             Wipro Ltd      0.56
# 19        Britannia Ind.      0.53
# 20   Kotak Mahindra Bank      0.39
# 21         Bharti Airtel      0.28

# %%
data.describe()
# Out:
#         % Change
# count  22.000000
# mean    1.887727
# std     1.584433
# min     0.280000
# 25%     0.722500
# 50%     1.230000
# 75%     2.840000
# max     6.190000

# %%
ax = data.plot.bar(x = 'Company', y = '% Change', title = 'Comparison')

# %%
# Colors for the bar plot
COLORS = ['orange', 'green', 'orange', 'cyan', 'cyan', 'blue', 'silver', 'orange', 'red', 'green']

# Plotting market_cap_usd as before but adding the colors and scaling the y-axis  
ax = data.plot.bar(x = 'Company', y = '% Change', title = 'Comparison',color=COLORS,logy=True)

# Annotating the y axis with 'USD'
ax.set_ylabel('USD')
# Final touch! Removing the xlabel as it is not very informative
ax.set_xlabel('')
# Out:
# Text(0.5,0,'')
